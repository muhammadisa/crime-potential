# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud, ImageColorGenerator
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
# %matplotlib inline

# %%
# data preparation
url = "https://raw.githubusercontent.com/muhammadisa/crime-potential/main/crime-potential.csv"
crimepotential = pd.read_csv(url)
crimepotential.head(5)
# Out:
#    person_arround  desinty_avg  night  gender condition
# 0               1          0.5      1       1    danger
# 1               5          0.1      1       0    danger
# 2              10          0.2      0       1      safe
# 3              20          1.0      1       1      safe
# 4               4          2.0      0       1      safe

# %%
# describe detail of data show you how much unique, top, req, count
crimepotential.describe()
# Out:
#        person_arround  desinty_avg      night     gender
# count       27.000000    27.000000  27.000000  27.000000
# mean        39.370370     3.085185   0.481481   0.481481
# std         48.532422     5.575613   0.509175   0.509175
# min          1.000000     0.100000   0.000000   0.000000
# 25%          4.500000     0.100000   0.000000   0.000000
# 50%         19.000000     0.800000   0.000000   0.000000
# 75%         66.500000     2.000000   1.000000   1.000000
# max        192.000000    20.000000   1.000000   1.000000

# %%
crimepotential.groupby('condition').describe().T
# Out:
# condition                danger        safe
# person_arround count   7.000000   20.000000
#                mean    7.000000   50.700000
#                std    10.115994   51.669089
#                min     1.000000    3.000000
#                25%     1.500000    7.750000
#                50%     2.000000   29.500000
#                75%     7.000000   90.000000
#                max    29.000000  192.000000
# desinty_avg    count   7.000000   20.000000
#                mean    3.400000    2.975000
#                std     7.350737    5.042647
#                min     0.100000    0.100000
#                25%     0.150000    0.100000
#                50%     0.500000    0.900000
#                75%     1.450000    2.250000
#                max    20.000000   20.000000
# night          count   7.000000   20.000000
#                mean    0.714286    0.400000
#                std     0.487950    0.502625
#                min     0.000000    0.000000
#                25%     0.500000    0.000000
#                50%     1.000000    0.000000
#                75%     1.000000    1.000000
#                max     1.000000    1.000000
# gender         count   7.000000   20.000000
#                mean    0.428571    0.500000
#                std     0.534522    0.512989
#                min     0.000000    0.000000
#                25%     0.000000    0.000000
#                50%     0.000000    0.500000
#                75%     1.000000    1.000000
#                max     1.000000    1.000000

# %%
crimepotential.isnull().values.any()
# Out:
# False

# %%
danger_condition = crimepotential[crimepotential.condition == "danger"]
safe_condition = crimepotential[crimepotential.condition == "safe"]

# %%
# we can observe imbalance data here
plt.figure(figsize=(8,6))
sns.countplot(crimepotential.condition)
(len(safe_condition)/len(danger_condition))*100
# Out:
# /home/stoic/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 285.7142857142857

# %%
feature_columns = ['person_arround','desinty_avg','night','gender']
predicted_class = ['condition']
